# %%
import pandas as pd
import numpy as np

import wrangle

# %%
ercot = wrangle.get_ercot_df()

# %%
ercot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 109535 entries, 2010-01-01 00:00:00 to 2022-06-30 23:00:00
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ercot_load      109535 non-null  float64
#  1   dow             109535 non-null  object
#  2   is_weekday      109535 non-null  int64
#  3   is_obs_holiday  109535 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 4.2+ MB

# %%
weather = pd.read_csv('clean_weather_df.csv',index_col='datetime',parse_dates=['datetime'])

# %%
weather.index.minute.value_counts()
# Out:
# 0    109536
# Name: datetime, dtype: int64

# %%
weather.loc['2017-11-05']
# Out:
#                      hs_temp  hs_feelslike  hs_dew  hs_humidity  hs_precip  \
# datetime
# 2017-11-05 00:00:00     74.2          74.2   73.30        97.13        0.0
# 2017-11-05 01:00:00     73.6          73.6   73.35        99.17        0.0
# 2017-11-05 02:00:00     73.6          73.6   73.40        99.24        0.0
# 2017-11-05 03:00:00     73.6          73.6   73.40        99.26        0.0
# 2017-11-05 04:00:00     73.6          73.6   73.40        99.12        0.0
# 2017-11-05 05:00:00     73.6          73.6   73.40        99.26        0.0
# 2017-11-05 06:00:00     73.6          73.6   73.40        99.26        0.0
# 2017-11-05 07:00:00     73.6          73.6   73.40        99.26        0.0
# 2017-11-05 08:00:00     75.3          75.3   73.50        94.28        0.0
# 2017-11-05 09:00:00     78.2          78.2   73.60        85.74        0.0
# 2017-11-05 10:00:00     80.2          84.0   71.90        76.08        0.0
# ...

# %%
weather.loc['2017-03-12']
# Out:
#                      hs_temp  hs_feelslike  hs_dew  hs_humidity  hs_precip  \
# datetime
# 2017-03-12 00:00:00     62.8          62.8    62.6        99.25       0.06
# 2017-03-12 01:00:00     62.6          62.6    62.3        99.16       0.01
# 2017-03-12 02:00:00      NaN           NaN     NaN          NaN        NaN
# 2017-03-12 03:00:00     59.0          59.0    57.1        93.56       0.00
# 2017-03-12 04:00:00     56.1          56.1    54.1        93.23       0.00
# 2017-03-12 05:00:00     53.6          53.6    50.8        90.16       0.00
# 2017-03-12 06:00:00     51.2          51.2    48.3        89.83       0.00
# 2017-03-12 07:00:00     50.2          50.2    46.7        87.51       0.00
# 2017-03-12 08:00:00     49.1          42.9    45.6        87.41       0.00
# 2017-03-12 09:00:00     48.3          42.1    44.8        87.84       0.00
# 2017-03-12 10:00:00     48.3          42.6    44.7        87.55       0.00
# ...

# %%
weather[weather.hs_temp.isna()].index
# Out:
# DatetimeIndex(['2010-03-14 02:00:00', '2011-03-13 02:00:00',
#                '2012-03-11 02:00:00', '2013-03-10 02:00:00',
#                '2014-03-09 02:00:00', '2015-03-08 02:00:00',
#                '2016-03-13 02:00:00', '2017-03-12 02:00:00',
#                '2018-03-11 02:00:00', '2019-03-10 02:00:00',
#                '2020-03-08 02:00:00', '2021-03-14 02:00:00',
#                '2022-03-13 02:00:00'],
#               dtype='datetime64[ns]', name='datetime', freq=None)

# %%
# df.drop(index=weather[weather.hs_temp.isna()].index)

# %%
tz_w = weather.copy()

# %%
tz_w.loc['2010-11-07']
# Out:
#                      hs_temp  hs_feelslike  hs_dew  hs_humidity  hs_precip  \
# datetime
# 2010-11-07 00:00:00    54.10         54.10    39.3       57.270        0.0
# 2010-11-07 01:00:00    54.05         54.05    37.8       54.045        0.0
# 2010-11-07 02:00:00    53.80         53.80    38.0       55.110        0.0
# 2010-11-07 03:00:00    53.80         53.80    38.0       55.110        0.0
# 2010-11-07 04:00:00    53.80         53.80    38.0       55.110        0.0
# 2010-11-07 05:00:00    52.20         52.20    40.8       65.130        0.0
# 2010-11-07 06:00:00    53.70         53.70    43.9       69.220        0.0
# 2010-11-07 07:00:00    50.70         50.70    39.6       65.550        0.0
# 2010-11-07 08:00:00    54.80         54.80    41.9       61.580        0.0
# 2010-11-07 09:00:00    58.80         58.80    41.3       52.250        0.0
# 2010-11-07 10:00:00    62.40         62.40    39.6       42.910        0.0
# ...

# %%
tz_w.tz_localize('US/Central',ambiguous='infer',nonexistent='NaT')
# Out:
# ---------------------------------------------------------------------------
# AmbiguousTimeError                        Traceback (most recent call last)
# /var/folders/dn/dr6y15951wq03xbh2xr9khq40000gn/T/ipykernel_67719/1661980962.py in <module>
# ----> 1 tz_w.tz_localize('US/Central',ambiguous='infer',nonexistent='NaT')
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in tz_localize(self, tz, axis, level, copy, ambiguous, nonexistent)
#    9692             if level not in (None, 0, ax.name):
#    9693                 raise ValueError(f"The level {level} is not valid")
# -> 9694             ax = _tz_localize(ax, tz, ambiguous, nonexistent)
#    9695
#    9696         result = self.copy(deep=copy)
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _tz_localize(ax, tz, ambiguous, nonexistent)
#    9680                     ax = DatetimeIndex([], tz=tz)
#    9681             else:
# ...

# %%
er_list = list(ercot.index)
w_list = list(weather.index)

# %%
len(er_list)
# Out:
# 109535

# %%
len(w_list)
# Out:
# 109536

# %%
set(w_list) - set(er_list)
# Out:
# {Timestamp('2010-03-14 02:00:00'),
#  Timestamp('2011-03-13 02:00:00'),
#  Timestamp('2012-03-11 02:00:00'),
#  Timestamp('2013-03-10 02:00:00'),
#  Timestamp('2014-03-09 02:00:00'),
#  Timestamp('2015-03-08 02:00:00'),
#  Timestamp('2016-03-13 02:00:00'),
#  Timestamp('2017-03-12 03:00:00'),
#  Timestamp('2018-03-11 03:00:00'),
#  Timestamp('2019-03-10 03:00:00'),
#  Timestamp('2020-03-08 03:00:00'),
#  Timestamp('2021-03-14 03:00:00'),
#  Timestamp('2022-03-13 03:00:00')}

# %%
ercot.loc['2010-11-07']
# Out:
#                       ercot_load     dow  is_weekday  is_obs_holiday
# datetime
# 2010-11-07 00:00:00  7487.208500  Sunday           0               0
# 2010-11-07 01:00:00  7218.432121  Sunday           0               0
# 2010-11-07 02:00:00  7051.515830  Sunday           0               0
# 2010-11-07 02:00:00  6914.202568  Sunday           0               0
# 2010-11-07 03:00:00  6881.075592  Sunday           0               0
# 2010-11-07 04:00:00  6886.134142  Sunday           0               0
# 2010-11-07 05:00:00  6975.323383  Sunday           0               0
# 2010-11-07 06:00:00  7161.669600  Sunday           0               0
# 2010-11-07 07:00:00  7366.010375  Sunday           0               0
# 2010-11-07 08:00:00  7523.301696  Sunday           0               0
# 2010-11-07 09:00:00  7786.921692  Sunday           0               0
# 2010-11-07 10:00:00  7963.236536  Sunday           0               0
# ...

# %%
import pytz

# %%
pytz.all_timezones
# Out:
# ['Africa/Abidjan', 'Africa/Accra', 'Africa/Addis_Ababa', 'Africa/Algiers', 'Africa/Asmara', 'Africa/Asmera', 'Africa/Bamako', 'Africa/Bangui', 'Africa/Banjul', 'Africa/Bissau', 'Africa/Blantyre', 'Africa/Brazzaville', 'Africa/Bujumbura', 'Africa/Cairo', 'Africa/Casablanca', 'Africa/Ceuta', 'Africa/Conakry', 'Africa/Dakar', 'Africa/Dar_es_Salaam', 'Africa/Djibouti', 'Africa/Douala', 'Africa/El_Aaiun', 'Africa/Freetown', 'Africa/Gaborone', 'Africa/Harare', 'Africa/Johannesburg', 'Africa/Juba', 'Africa/Kampala', 'Africa/Khartoum', 'Africa/Kigali', 'Africa/Kinshasa', 'Africa/Lagos', 'Africa/Libreville', 'Africa/Lome', 'Africa/Luanda', 'Africa/Lubumbashi', 'Africa/Lusaka', 'Africa/Malabo', 'Africa/Maputo', 'Africa/Maseru', 'Africa/Mbabane', 'Africa/Mogadishu', 'Africa/Monrovia', 'Africa/Nairobi', 'Africa/Ndjamena', 'Africa/Niamey', 'Africa/Nouakchott', 'Africa/Ouagadougou', 'Africa/Porto-Novo', 'Africa/Sao_Tome', 'Africa/Timbuktu', 'Africa/Tripoli', 'Africa/Tunis', 'Africa/Windhoek', 'Ame
# ...

# %%
ercot.loc['2017-03-12']
# Out:
#                       ercot_load     dow  is_weekday  is_obs_holiday
# datetime
# 2017-03-12 00:00:00  9120.385718  Sunday           0               0
# 2017-03-12 01:00:00  8579.644600  Sunday           0               0
# 2017-03-12 02:00:00  8251.748166  Sunday           0               0
# 2017-03-12 04:00:00  8016.291377  Sunday           0               0
# 2017-03-12 05:00:00  7894.080492  Sunday           0               0
# 2017-03-12 06:00:00  7871.827685  Sunday           0               0
# 2017-03-12 07:00:00  8034.402546  Sunday           0               0
# 2017-03-12 08:00:00  8192.101434  Sunday           0               0
# 2017-03-12 09:00:00  8395.224430  Sunday           0               0
# 2017-03-12 10:00:00  8817.761577  Sunday           0               0
# 2017-03-12 11:00:00  9218.897392  Sunday           0               0
# 2017-03-12 12:00:00  9535.095465  Sunday           0               0
# ...

# %%
ercot.loc['2017-11-05']
# Out:
#                        ercot_load     dow  is_weekday  is_obs_holiday
# datetime
# 2017-11-05 00:00:00  11692.944342  Sunday           0               0
# 2017-11-05 01:00:00  11086.848799  Sunday           0               0
# 2017-11-05 02:00:00  10677.703425  Sunday           0               0
# 2017-11-05 02:00:00  10377.230056  Sunday           0               0
